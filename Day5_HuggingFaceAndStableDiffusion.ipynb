# %% [markdown]
# # Hugging face

# %%
# !pip install transformers

# %%
from transformers import pipeline
classifier = pipeline('sentiment-analysis')
result = classifier("I love deep learning but I hate maths but again i love NLP")
# result
print(f"label:{result[0]['label']},with score:{round(result[0]['score'],4)}")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# ...

# %%
from transformers import pipeline
classifier = pipeline('sentiment-analysis')
result = classifier("I love deep learning but I hate maths but again i love NLP")
result

print(f"label:{result[0]['label']},with score:{round(result[0]['score'],4)}")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# label:POSITIVE,with score:0.9973

# %%
classifier.model.name_or_path
# Out:
# 'distilbert/distilbert-base-uncased-finetuned-sst-2-english'

# %%
from transformers import pipeline
classifier = pipeline('sentiment-analysis',model="avichr/heBERT_sentiment_analysis")
result = classifier("love machine learning")
result
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'label': 'positive', 'score': 0.9971224665641785}]

# %% [markdown]
# text-classification
#
# summarization
#
# text-generation
#
# object-detection
#
# image-classification
#
# document-question-answering
#
# image to text

# %%
from transformers import pipeline
classifier = pipeline('text-classification')
result = classifier("I love deep learning but I hate maths but again i love NLP")
print(result)

result2 = classifier("This is bad")
result2
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'label': 'POSITIVE', 'score': 0.9973329305648804}]
# [{'label': 'NEGATIVE', 'score': 0.9997872710227966}]

# %%
from transformers import pipeline
summarization = pipeline('summarization')
result = summarization("Once upon a time there was an old mother pig who had three little pigs and not enough food to feed them. So when they were old enough, she sent them out into the world to seek their fortunes." +

"The first little pig was very lazy. He didn't want to work at all and he built his house out of straw. The second little pig worked a little bit harder but he was somewhat lazy too and he built his house out of sticks. Then, they sang and danced and played together the rest of the day."

+"The third little pig worked hard all day and built his house with bricks. It was a sturdy house complete with a fine fireplace and chimney. It looked like it could withstand the strongest winds.")
result
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'summary_text': " Once upon a time there was an old mother pig who had three little pigs and not enough food to feed them . So when they were old enough, she sent them out into the world to seek their fortunes . The first little pig was very lazy. He didn't want to work at all and he built his house out of straw . The second little pig worked a little bit harder but he was somewhat lazy too . They sang and danced and played together the rest of the day ."}]

# %%
from transformers import pipeline

summarization = pipeline('summarization')
text = (
    "Once upon a time there was an old mother pig who had three little pigs and not enough food to feed them. "
    "So when they were old enough, she sent them out into the world to seek their fortunes. "
    "The first little pig was very lazy. He didn't want to work at all and he built his house out of straw. "
    "The second little pig worked a little bit harder but he was somewhat lazy too and he built his house out of sticks. "
    "Then, they sang and danced and played together the rest of the day. "
    "The third little pig worked hard all day and built his house with bricks. It was a sturdy house complete with a fine fireplace and chimney. "
    "It looked like it could withstand the strongest winds."
)

result = summarization(text, max_length=50, min_length=25, do_sample=False)
result
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'summary_text': ' Once upon a time there was an old mother pig who had three little pigs and not enough food to feed them . So when they were old enough, she sent them out into the world to seek their fortunes . The first little pig was'}]

# %%
from transformers import pipeline
generator = pipeline('text-generation')
result = generator("I love deep learning but I hate maths but again i love NLP", max_length=200, num_return_sequences=1)
result
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 6c0e608 (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
# !pip install timm

# %%
from transformers import pipeline
from PIL import Image
import requests
from io import BytesIO

# %%
from transformers import pipeline
objectDetection = pipeline('object-detection')
result = objectDetection("https://img.freepik.com/free-photo/abstract-autumn-beauty-multi-colored-leaf-vein-pattern-generated-by-ai_188544-9871.jpg")
print(result)
# Out:
# No model was supplied, defaulted to facebook/detr-resnet-50 and revision 2729413 (https://huggingface.co/facebook/detr-resnet-50).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some weights of the model checkpoint at facebook/detr-resnet-50 were not used when initializing DetrForObjectDetection: ['model.backbone.conv_encoder.model.layer1.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer2.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer3.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer4.0.downsample.1.num_batches_tracked']
# - This IS expected if you are initializing DetrForObjectDetection from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
imageClassification = pipeline('image-classification')
result = imageClassification("https://img.freepik.com/free-photo/abstract-autumn-beauty-multi-colored-leaf-vein-pattern-generated-by-ai_188544-9871.jpg")
print(result)
# Out:
# No model was supplied, defaulted to google/vit-base-patch16-224 and revision 5dca96d (https://huggingface.co/google/vit-base-patch16-224).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'label': 'quill, quill pen', 'score': 0.9971115589141846}, {'label': 'coil, spiral, volute, whorl, helix', 'score': 7.78357352828607e-05}, {'label': 'red wine', 'score': 5.748767944169231e-05}, {'label': 'fountain pen', 'score': 5.07562181155663e-05}, {'label': 'letter opener, paper knife, paperknife', 'score': 5.058090391685255e-05}]

# %%
document = (
    "The Eiffel Tower is a wrought-iron lattice tower on the Champ de Mars in Paris, France. "
    "It was named after the engineer Gustave Eiffel, whose company designed and built the tower. "
    "Construction of the tower began in January 1887 and was completed in March 1889. "
    "The Eiffel Tower is 324 meters tall, and it was the tallest man-made structure in the world until 1930."
)

question = "Who designed the Eiffel Tower?"

qa_pipeline = pipeline('question-answering')
result = qa_pipeline(question=question, context=document)

print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# {'score': 0.9913378953933716, 'start': 120, 'end': 134, 'answer': 'Gustave Eiffel'}

# %%
imageToText = pipeline('image-to-text')
result = imageToText("https://img.freepik.com/free-photo/abstract-autumn-beauty-multi-colored-leaf-vein-pattern-generated-by-ai_188544-9871.jpg")

print(result)
# Out:
# No model was supplied, defaulted to ydshieh/vit-gpt2-coco-en and revision 65636df (https://huggingface.co/ydshieh/vit-gpt2-coco-en).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/4.34k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/982M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/236 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/211 [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# ...

# %%
from transformers import pipeline

# Initialize the text2text-generation pipeline with the code reviewer model
pipe = pipeline("text2text-generation", model="microsoft/codereviewer", device=0)

# Example input text (code)
input_code = "def add(a, b):\n    return a + b"

# Use the pipeline to generate text (review the code)
result = pipe(input_code)

# Print the result
print(result)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [{'generated_text': '<e0>"""'}]

# %% [markdown]
# Convert languague using googles model

# %%
from transformers import pipeline

# Initialize the text2text-generation pipeline with the FLAN-T5 model and GPU support
pipe = pipeline("text2text-generation", model="google/flan-t5-large", device=0)  # device=0 uses the first GPU

# Example input text
input_text = "Translate this text to French: 'Hello, how are you?'"

# Generate text
result = pipe(input_text)

# Print the result
print(result)
# Out:
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# [{'generated_text': "« Bienvenue, c'est-ce que vous?»"}]

# %%
from transformers import pipeline

# Initialize the fill-mask pipeline with the specified model
pipe = pipeline("fill-mask", model="google/bert_uncased_L-12_H-768_A-12")

# Define the input text with a [MASK] token where the model should predict the missing word
input_text = "The capital of France is [MASK]."

# Generate predictions using the pipeline
output = pipe(input_text)

# Print the original text and the model's top predictions
print("Original Text:")
print(input_text)
print("\nTop Predictions:")

for i, prediction in enumerate(output):
    print(f"{i + 1}: {prediction['sequence']} (Score: {prediction['score']:.4f})")
# Out:
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Original Text:
# The capital of France is [MASK].
#
# Top Predictions:
# 1: the capital of france is paris. (Score: 0.1627)
# 2: the capital of france is lille. (Score: 0.1225)
# 3: the capital of france is marseille. (Score: 0.0833)
# 4: the capital of france is lyon. (Score: 0.0799)
# 5: the capital of france is toulouse. (Score: 0.0784)

# %%
# !pip install python-pptx transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 12.6 MB/s eta 0:00:00
# ...

# %%
from pptx import Presentation
from pptx.util import Inches
from transformers import pipeline

# Initialize the text generation pipeline
generator = pipeline("text2text-generation", model="google/flan-t5-large", device=0)

# Define prompts for each slide
prompts = {
    "Introduction to Hugging Face": "Provide a brief introduction to Hugging Face and its significance in natural language processing.",
    "Transformers Library": "Explain what the Transformers library is, its key features, and benefits.",
    "Popular Models": "List and describe popular models available on Hugging Face such as BERT, GPT-3, T5, and RoBERTa.",
    "BERT (Bidirectional Encoder Representations from Transformers)": "Describe BERT and its use cases in NLP tasks.",
    "GPT (Generative Pre-trained Transformer)": "Describe GPT and its applications in text generation.",
    "T5 (Text-To-Text Transfer Transformer)": "Explain T5 and its capabilities for various NLP tasks.",
    "RoBERTa (Robustly optimized BERT approach)": "Discuss RoBERTa and its improvements over BERT.",
    "Pipeline API": "Explain the `pipeline` API in Hugging Face and how it is used for different NLP tasks.",
    "Use Cases and Applications": "Provide real-world applications of Hugging Face models.",
    "Setting Up and Using Models": "Outline the steps to load and use models from Hugging Face.",
    "Challenges and Considerations": "Discuss challenges and considerations when working with Hugging Face models.",
    "Future Directions": "Highlight future directions in NLP and AI related to Hugging Face models.",
    "Resources and Further Reading": "List resources and further reading materials related to Hugging Face and NLP.",
    "Q&A": "Provide space for questions and answers."
}

# Function to generate content using the model
def generate_content(prompt):
    result = generator(prompt, max_length=300)
    return result[0]['generated_text']

# Create a presentation object
prs = Presentation()

# Function to add a slide
def add_slide(prs, title, content):
    slide_layout = prs.slide_layouts[1]  # Use layout 1 for title and content
    slide = prs.slides.add_slide(slide_layout)
    title_placeholder = slide.shapes.title
    content_placeholder = slide.placeholders[1]
    title_placeholder.text = title
    content_placeholder.text = content

# Generate content and create slides
for title, prompt in prompts.items():
    content = generate_content(prompt)
    add_slide(prs, title, content)

# Save presentation
prs.save('Hugging_Face_Models_Presentation.pptx')

print("Presentation created successfully!")
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Presentation created successfully!

# %%
from pptx import Presentation
from pptx.util import Pt
from pptx.dml.color import RGBColor
from pptx.enum.text import PP_ALIGN
from transformers import pipeline
import torch

# Initialize the text generation pipeline with GPU if available
generator = pipeline("text2text-generation", model="google/flan-t5-large", device=0)

# Define prompts for each slide
prompts = {
    "Introduction to Hugging Face": "Provide a brief introduction to Hugging Face and its significance in natural language processing.",
    "Transformers Library": "Explain what the Transformers library is, its key features, and benefits.",
    "Popular Models": "List and describe popular models available on Hugging Face such as BERT, GPT-3, T5, and RoBERTa.",
    "BERT (Bidirectional Encoder Representations from Transformers)": "Describe BERT and its use cases in NLP tasks.",
    "GPT (Generative Pre-trained Transformer)": "Describe GPT and its applications in text generation.",
    "T5 (Text-To-Text Transfer Transformer)": "Explain T5 and its capabilities for various NLP tasks.",
    "RoBERTa (Robustly optimized BERT approach)": "Discuss RoBERTa and its improvements over BERT.",
    "Pipeline API": "Explain the `pipeline` API in Hugging Face and how it is used for different NLP tasks.",
    "Use Cases and Applications": "Provide real-world applications of Hugging Face models.",
    "Setting Up and Using Models": "Outline the steps to load and use models from Hugging Face.",
    "Challenges and Considerations": "Discuss challenges and considerations when working with Hugging Face models.",
    "Future Directions": "Highlight future directions in NLP and AI related to Hugging Face models.",
    "Resources and Further Reading": "List resources and further reading materials related to Hugging Face and NLP.",
    "Q&A": "Provide space for questions and answers."
}

# Function to generate content using the model
def generate_content(prompt):
    result = generator(prompt, max_length=300)
    return result[0]['generated_text']

# Create a presentation object
prs = Presentation()

# Function to add a slide with styling
def add_styled_slide(prs, title, content):
    slide_layout = prs.slide_layouts[1]  # Use layout 1 for title and content
    slide = prs.slides.add_slide(slide_layout)

    # Title styling
    title_placeholder = slide.shapes.title
    title_placeholder.text = title
    title_text_frame = title_placeholder.text_frame
    title_text_frame.paragraphs[0].font.size = Pt(44)
    title_text_frame.paragraphs[0].font.bold = True
    title_text_frame.paragraphs[0].font.color.rgb = RGBColor(0, 51, 102)  # Dark Blue

    # Content styling
    content_placeholder = slide.placeholders[1]
    content_placeholder.text = content
    content_text_frame = content_placeholder.text_frame
    content_text_frame.paragraphs[0].font.size = Pt(32)
    content_text_frame.paragraphs[0].font.color.rgb = RGBColor(0, 0, 0)  # Black
    content_text_frame.paragraphs[0].alignment = PP_ALIGN.LEFT

# Generate content and create slides
for title, prompt in prompts.items():
    content = generate_content(prompt)
    add_styled_slide(prs, title, content)

# Save presentation
prs.save('Styled_Hugging_Face_Models_Presentation.pptx')

print("Styled presentation created successfully!")
# Out:
# Styled presentation created successfully!

# %%
from pptx import Presentation
from pptx.util import Pt
from pptx.dml.color import RGBColor
from pptx.enum.text import PP_ALIGN
from transformers import pipeline
import torch
from datetime import datetime

# Check if GPU is available and set the device
device = 0

# Initialize the text generation pipeline with GPU if available
generator = pipeline("text2text-generation", model="google/flan-t5-large", device=device)

# Define prompts for each slide
prompts = {
    "Introduction to Hugging Face": "Provide a brief introduction to Hugging Face and its significance in natural language processing.",
    "Transformers Library": "Explain what the Transformers library is, its key features, and benefits.",
    "Popular Models": "List and describe popular models available on Hugging Face such as BERT, GPT-3, T5, and RoBERTa.",
    "BERT (Bidirectional Encoder Representations from Transformers)": "Describe BERT and its use cases in NLP tasks.",
    "GPT (Generative Pre-trained Transformer)": "Describe GPT and its applications in text generation.",
    "T5 (Text-To-Text Transfer Transformer)": "Explain T5 and its capabilities for various NLP tasks.",
    "RoBERTa (Robustly optimized BERT approach)": "Discuss RoBERTa and its improvements over BERT.",
    "Pipeline API": "Explain the `pipeline` API in Hugging Face and how it is used for different NLP tasks.",
    "Use Cases and Applications": "Provide real-world applications of Hugging Face models.",
    "Setting Up and Using Models": "Outline the steps to load and use models from Hugging Face.",
    "Challenges and Considerations": "Discuss challenges and considerations when working with Hugging Face models.",
    "Future Directions": "Highlight future directions in NLP and AI related to Hugging Face models.",
    "Resources and Further Reading": "List 2 resources and further reading materials related to Hugging Face and NLP.",
    "Q&A": "Provide space for questions and answers."
}

# Function to generate content using the model
def generate_content(prompt):
    result = generator(prompt, max_length=300)
    return result[0]['generated_text']

# Create a presentation object
prs = Presentation()

# Function to add a title slide
def add_title_slide(prs, heading, date):
    slide_layout = prs.slide_layouts[0]  # Title Slide layout
    slide = prs.slides.add_slide(slide_layout)

    # Title styling
    title_placeholder = slide.shapes.title
    title_placeholder.text = heading
    title_text_frame = title_placeholder.text_frame
    title_text_frame.paragraphs[0].font.size = Pt(56)
    title_text_frame.paragraphs[0].font.bold = True
    title_text_frame.paragraphs[0].font.color.rgb = RGBColor(0, 51, 102)  # Dark Blue

    # Date styling
    subtitle_placeholder = slide.placeholders[1]
    subtitle_placeholder.text = date
    subtitle_text_frame = subtitle_placeholder.text_frame
    subtitle_text_frame.paragraphs[0].font.size = Pt(32)
    subtitle_text_frame.paragraphs[0].font.color.rgb = RGBColor(0, 51, 102)  # Dark Blue
    subtitle_text_frame.paragraphs[0].alignment = PP_ALIGN.CENTER

# Function to add a slide with styling
def add_styled_slide(prs, title, content):
    slide_layout = prs.slide_layouts[1]  # Use layout 1 for title and content
    slide = prs.slides.add_slide(slide_layout)

    # Title styling
    title_placeholder = slide.shapes.title
    title_placeholder.text = title
    title_text_frame = title_placeholder.text_frame
    title_text_frame.paragraphs[0].font.size = Pt(44)
    title_text_frame.paragraphs[0].font.bold = True
    title_text_frame.paragraphs[0].font.color.rgb = RGBColor(0, 51, 102)  # Dark Blue

    # Content styling
    content_placeholder = slide.placeholders[1]
    content_placeholder.text = content
    content_text_frame = content_placeholder.text_frame
    content_text_frame.paragraphs[0].font.size = Pt(32)
    content_text_frame.paragraphs[0].font.color.rgb = RGBColor(0, 0, 0)  # Black
    content_text_frame.paragraphs[0].alignment = PP_ALIGN.LEFT

# Add title slide
heading = "Introduction to Hugging Face Models"
date = datetime.now().strftime("%B %d, %Y")
add_title_slide(prs, heading, date)

# Generate content and create slides
for title, prompt in prompts.items():
    content = generate_content(prompt)
    add_styled_slide(prs, title, content)

# Save presentation
prs.save('Styled_Hugging_Face_Models_Presentation.pptx')

print("Styled presentation created successfully!")
# Out:
# Styled presentation created successfully!

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch
from pptx import Presentation
from pptx.util import Inches

# Load pre-trained model and tokenizer
model_name = "gpt2"  # You can use "gpt2", "gpt2-medium", "gpt2-large", "gpt2-xl" or any other compatible model
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Function to generate text
def generate_text(prompt, max_length=100, num_return_sequences=1):
    input_ids = tokenizer.encode(prompt, return_tensors="pt").to(device)
    outputs = model.generate(
        input_ids,
        max_length=max_length,
        num_return_sequences=num_return_sequences,
        pad_token_id=tokenizer.eos_token_id,
        no_repeat_ngram_size=2,
        early_stopping=True,
        do_sample=True,         # Enable sampling
        top_k=50,               # Use top-k sampling
        temperature=0.7         # Control the randomness of predictions
    )
    return [tokenizer.decode(output, skip_special_tokens=True) for output in outputs]

# Get user input for the prompt
prompt = input("Enter a prompt: ")

# Get user input for the number of samples
n = int(input("Enter the number of slides to generate: "))

# Generate text based on the prompt
generated_texts = generate_text(prompt, num_return_sequences=n)

# Save the generated texts to files and create PowerPoint
prs = Presentation()

for i, text in enumerate(generated_texts):
    # Save to text files
    filename = f"slide_{i+1}.txt"
    with open(filename, "w") as file:
        file.write(text)
    print(f"Saved generated text as {filename}")

    # Add a slide for each text
    slide_layout = prs.slide_layouts[5]  # Use the "Title Slide" layout
    slide = prs.slides.add_slide(slide_layout)
    title = slide.shapes.title
    textbox = slide.shapes.add_textbox(Inches(1), Inches(2), Inches(8.5), Inches(5.5))
    text_frame = textbox.text_frame

    title.text = f"slide {i+1}"
    text_frame.text = text

# Save the PowerPoint presentation
pptx_filename = "PPT.pptx"
prs.save(pptx_filename)
print(f"Saved PowerPoint presentation as {pptx_filename}")
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Enter a prompt: Create information on AI
# Enter the number of slides to generate: 10
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:588: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# ...

# %% [markdown]
# # Stable Diffusion

# %%
# !pip install diffusers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 26.7 MB/s eta 0:00:00
# ...

# %%
import torch
from diffusers import StableDiffusionPipeline


# Load the stable diffusion pipeline
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16)
pipe = pipe.to("cuda")  # Move the model to GPU if available


# Define the prompt
prompt = "A futuristic city with flying cars at sunset"


# Generate the image from text
image = pipe(prompt).images[0]


# Save or display the image
image.save("generated_image.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
